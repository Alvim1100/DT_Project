# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv

load_dotenv()

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope="user-library-read"))

# %%
DT_uri = '2aaLAng2L2aWD2FClzwiep'

results = sp.album(DT_uri)
print(results)
